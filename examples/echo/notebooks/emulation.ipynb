# %% [markdown]
# ## Emulate with ECLYPSE
#
# This notebook will walk you through the process of setting up and running your first _emulation_ using ECLYPSE, which is pretty similar to a _simulation_.
#
# In this second notebook we focus on the **remote** simulation, which operates like the local one, but the applications are executed on remote nodes using Ray. This allows you to run simulations on a cluster of machines, which can be useful for large-scale simulations. It also performs operations on the services placed on the infrastructure, such as deploying, starting, stopping and undeploying them.
#
# The main difference between local and remote simulations (for the user, but not under the hood ;) is that in the remote one, **you must provide the logic for each service** in the applications you want to deploy.
#
# To make everything reproducible, we fix a SEED for the emulation. Try to change the SEED and see how the results change!

# %%
# Seed for the simulation
SEED = 2

# %% [markdown]
# ## Build an Infrastructure
#
# The infrastructure represents the computing resources on which the application(s) will be deployed.
# To define an infrastructure, you need to specify its nodes and links, together with the update policy that will be applied to the infrastructure.
#
# First of all, define an update policy that randomly changes the nodes and links resources.
# To do so we just have to define two functions, taking as argument a `networkx.NodeView` and a `networkx.EdgeView`, respectively, and returning the updated set of nodes and edges.

# %%
import random as rnd

from networkx.classes.reportviews import (
    EdgeView,
    NodeView,
)


# update edges
def node_random_update(nodes: NodeView):
    for _, resources in nodes.data():
        if rnd.random() < 0.02:
            resources["availability"] = 0
        elif rnd.random() < 0.5 and resources["availability"] == 0:
            resources["availability"] = 1
        else:
            # Randomly update resources with different ranges
            resources["cpu"] = round(max(0, resources["cpu"] * rnd.uniform(0.95, 1.05)))
            resources["gpu"] = round(max(0, resources["gpu"] * rnd.uniform(0.9, 1.1)))
            resources["ram"] = round(max(0, resources["ram"] * rnd.uniform(0.8, 1.2)))
            resources["storage"] = round(
                max(0, resources["storage"] * rnd.uniform(0.9, 1.1))
            )
            resources["availability"] = min(
                1, max(0, resources["availability"] * rnd.uniform(0.995, 1.005))
            )


def edge_random_update(edges: EdgeView):
    for _, _, resources in edges.data():
        # Randomly update resources with different ranges
        resources["latency"] = round(
            max(0, resources["latency"] * rnd.uniform(0.9, 1.1))
        )
        resources["bandwidth"] = round(
            max(0, resources["bandwidth"] * rnd.uniform(0.95, 1.05))
        )

# %% [markdown]
# Now you can define the topology, by adding ndoes and links to an extend `networx.Graph`, that is our `eclypse.graph.Infrastructure` class.
# The previsouly defined update policies will be parameters of the Infrastructure builder.

# %%
from eclypse.graph import Infrastructure, NodeGroup

echo_infra = Infrastructure(
    "EchoInfrastructure",
    node_update_policy=node_random_update,
    edge_update_policy=edge_random_update,
    seed=SEED,
)
echo_infra.add_node_by_group(NodeGroup.CLOUD, "CloudServer")
echo_infra.add_node_by_group(NodeGroup.FAR_EDGE, "EdgeGateway")
echo_infra.add_node_by_group(NodeGroup.IOT, "IoTDevice")
echo_infra.add_node_by_group(NodeGroup.CLOUD, "CloudStorage")
echo_infra.add_node_by_group(NodeGroup.NEAR_EDGE, "EdgeSensor")

echo_infra.add_symmetric_edge("CloudServer", "EdgeGateway", latency=5.0, bandwidth=80.0)
echo_infra.add_symmetric_edge("EdgeGateway", "IoTDevice", latency=8.0, bandwidth=50.0)
echo_infra.add_symmetric_edge(
    "IoTDevice", "CloudStorage", latency=15.0, bandwidth=100.0
)
echo_infra.add_symmetric_edge("CloudStorage", "EdgeSensor", latency=9.0, bandwidth=70.0)
# Out:
# 2024-11-25 17:18:25,770	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# ## Define the Application (and its Services)
#
# The second step is to define the application that will be placed on the infrastructure. Similarly to the infrastructure, the application is defined by a set of components (services) and edges (interactions), and an update policy that will be applied to the application. In this example we do not change the application requirements, so no update policy is defined.
#
# The application is an instance of another extended graph, specifically the `eclypse.graph.Application` class.
#
# **N.B.** Since we are in a _remote_ simulation, we must implement each service. For simplicity we define one trivial logic that is assigned to all the services.
# Such a logic just send an "hello" message to all the neighbours, in both unicast and broadcast mode, printing the received messages and the times to send the messages.
# To implement a service logic, you have to extend the `eclypse.remote.service.Service` class and implement the `dispatch` method.

# %%
import asyncio
import time

from eclypse.remote.service import Service


class EchoService(Service):
    def __init__(self, id: str):
        super().__init__(id, store_step=True)
        self.i = 0

    async def step(self):
        message = {"message": f"Hello from {self.id}!"}

        neigh = await self.mpi.get_neighbors()
        expected_wait_unicast = 0
        t_init_unicast = time.time()
        for n in neigh:
            req = await self.mpi.send(n, message)
            expected_wait_unicast += req.route.cost(message) if req.route else 0
        t_final_unicast = time.time()
        t_unicast = t_final_unicast - t_init_unicast
        self.logger.info(
            f"Service {self.id}, {self.i} -  Unicasts in: {t_unicast}, expected = {expected_wait_unicast}"
        )
        t_init_broadcast = time.time()
        req = await self.mpi.send(neigh, message)
        expected_wait_broadcast = max(
            [r.cost(message) for r in req.routes if r], default=0
        )
        t_final_broadcast = time.time()
        t_broadcast = t_final_broadcast - t_init_broadcast
        self.logger.info(
            f"Service {self.id}, {self.i} - Broadcasts in: {t_broadcast}, expected = {expected_wait_broadcast}"
        )
        self.i += 1
        await asyncio.sleep(1)
        return (
            self.i,
            t_unicast,
            expected_wait_unicast,
            t_broadcast,
            expected_wait_broadcast,
        )

# %%
from eclypse.graph import Application, NodeGroup

echo_app = Application("EchoApp")

echo_app.add_service(
    EchoService("Gateway"),
    cpu=1,
    gpu=0,
    ram=0.5,
    storage=0.5,
    availability=0.9,
    group=NodeGroup.IOT,
    processing_time=0.1,
)

echo_app.add_service(
    EchoService("SecurityService"),
    cpu=2,
    gpu=0,
    ram=4.0,
    storage=2.0,
    availability=0.8,
    group=NodeGroup.NEAR_EDGE,
    processing_time=2.0,
)

echo_app.add_service(
    EchoService("LightingService"),
    cpu=1,
    gpu=0,
    ram=2.0,
    storage=5.0,
    availability=0.8,
    group=NodeGroup.IOT,
    processing_time=1.0,
)

echo_app.add_service(
    EchoService("ClimateControlService"),
    cpu=2,
    gpu=0,
    ram=3.0,
    storage=8.0,
    availability=0.85,
    group=NodeGroup.NEAR_EDGE,
    processing_time=1.5,
)


echo_app.add_service(
    EchoService("EntertainmentService"),
    cpu=3,
    gpu=1,
    ram=4.0,
    storage=10.0,
    availability=0.9,
    group=NodeGroup.CLOUD,
    processing_time=5.0,
)

echo_app.add_symmetric_edge(
    "Gateway",
    "LightingService",
    latency=100.0,
    bandwidth=20.0,
)

echo_app.add_symmetric_edge(
    "Gateway",
    "ClimateControlService",
    latency=100.0,
    bandwidth=10.0,
)

echo_app.add_symmetric_edge(
    "Gateway",
    "SecurityService",
    latency=50.0,
    bandwidth=5.0,
)

echo_app.add_symmetric_edge(
    "SecurityService",
    "EntertainmentService",
    latency=50.0,
    bandwidth=10.0,
)

# %% [markdown]
# ## Configure and run the simulation
#
# After you define your application(s) and infrastructure, in order to run the simulation, you need to **configure** your simulation by specifying parameters such as its duration, the report and logging features, and other additional settings.
# To do so, it is necessary to define an instance of the `eclypse.simualation.SimulationConfig` class, specifying all possible parameters in the constructor.
#
# For example, if you want to run a **remote** simulation lasting 100 ticks, each every 250ms, save the report in `./my-rmeote-simulation` folder and set a _seed_ for pseudo-randomness, you will have to configure the simulation as follows.
#
# **N.B.** We introduced a delay between ticks, to allow services to execute their logics.

# %%
from eclypse.simulation import SimulationConfig
from eclypse.utils import DEFAULT_SIM_PATH

sim_config = SimulationConfig(
    seed=SEED,
    max_ticks=100,
    tick_every_ms=250,
    path="./my-remote-simulation",
    remote=True,
    )

# %% [markdown]
# Then create an instance of the `eclypse.simulation.Simulation` class, passing the infrastructur and the configuration as arguments:

# %%
from eclypse.simulation import Simulation

simulation = Simulation(infrastructure=echo_infra, simulation_config=sim_config)
# Out:
# 2024-11-25 17:18:27,085	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2024-11-25 17:18:27,654	WARNING actor.py:653 -- Creating an actor from class RemoteSimulator overwrites attribute remote of that class

# %% [markdown]
# Now that you have a Simulation object, you can include the application(s) in the simulation by calling the `register` method, passing the application object as an argument, and specifying the **placement strategy** to use. In this case we use one of the off-the-shelf placement strategies provided by ECLYPSE, the `eclypse.placement.strategies.RandomStrategy`:

# %%
from eclypse.placement.strategies import RandomStrategy

strategy = RandomStrategy(seed=SEED)

simulation.register(echo_app, placement_strategy=strategy)
# Out:
# (RemoteNode pid=60507) 17:18:28 | 🌘 ECLYPSE | CloudServer - Node CloudServer created.
# (RemoteNode pid=60506) 17:18:28 | 🌘 ECLYPSE | EdgeGateway - Node EdgeGateway created.
# (RemoteNode pid=60508) 17:18:28 | 🌘 ECLYPSE | IoTDevice - Node IoTDevice created.
# (RemoteNode pid=60509) 17:18:28 | 🌘 ECLYPSE | CloudStorage - Node CloudStorage created.
# (RemoteNode pid=60510) 17:18:28 | 🌘 ECLYPSE | EdgeSensor - Node EdgeSensor created.
# (RemoteSimulator pid=60511) 17:18:28 | 🌘 ECLYPSE | Simulation - Event Start-0 fired.
# (RemoteSimulator pid=60511) 17:18:28 | 🌘 ECLYPSE | Simulation - Event Tick-0 fired.
# (RemoteSimulator pid=60511) 17:18:28 | 🌘 ECLYPSE | Simulation - Event Enact-0 fired.
# (RemoteSimulator pid=60511) 17:18:28 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:28 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 4.5, 'storage': 10.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:28 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 31, 'ram': 66, 'storage': 2244, 'gpu': 25, 'availability': 0.9777402078805711, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Tick-1 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Enact-1 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 2.0, 'ram': 3.0, 'storage': 8.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.5, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 7, 'storage': 103, 'gpu': 2, 'availability': 0.9515947882565854, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 6.0, 'storage': 15.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 58, 'storage': 131, 'gpu': 14, 'availability': 0.958164825752737, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Tick-2 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Enact-2 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 7.0, 'ram': 11.0, 'storage': 20.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.5, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 7, 'storage': 104, 'gpu': 2, 'availability': 0.9543732834804775, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Tick-3 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Enact-3 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 5.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 6, 'storage': 100, 'gpu': 2, 'availability': 0.9573901695660472, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Tick-4 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | Simulation - Event Enact-4 fired.
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 5.0, 'ram': 7.0, 'storage': 18.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.5, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:29 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 36, 'storage': 128, 'gpu': 11, 'availability': 0.9617362646871156, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Tick-5 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Enact-5 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 7.0, 'ram': 11.0, 'storage': 20.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.5, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 7, 'storage': 103, 'gpu': 2, 'availability': 0.9588837678119033, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Tick-6 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Enact-6 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 4.5, 'storage': 10.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 31, 'ram': 51, 'storage': 2195, 'gpu': 24, 'availability': 0.9766664880439309, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Tick-7 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Enact-7 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 6.0, 'storage': 15.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 30, 'ram': 50, 'storage': 2295, 'gpu': 22, 'availability': 0.9778280999665516, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 7.0, 'storage': 10.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.5, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 5, 'storage': 102, 'gpu': 2, 'availability': 0.9515988814059193, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Tick-8 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | Simulation - Event Enact-8 fired.
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 5.0, 'ram': 8.0, 'storage': 12.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 2.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:30 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 30, 'ram': 54, 'storage': 2186, 'gpu': 24, 'availability': 0.9756760575802519, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | Simulation - Event Tick-9 fired.
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | Simulation - Event Enact-9 fired.
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 5.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 30, 'ram': 57, 'storage': 2287, 'gpu': 22, 'availability': 0.9748030880349965, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 5.0, 'ram': 9.0, 'storage': 15.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.0, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 6, 'storage': 106, 'gpu': 2, 'availability': 0.9429224761839349, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | Simulation - Event Tick-10 fired.
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | Simulation - Event Enact-10 fired.
# (CloudServer pid=60507) 17:18:31 | INFO | EntertainmentService - Service EntertainmentService, 0 -  Unicasts in: 0.002714872360229492, expected = 0
# (CloudServer pid=60507) 17:18:31 | INFO | EntertainmentService - Service EntertainmentService, 0 - Broadcasts in: 0.0012209415435791016, expected = 0
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeSensor | SecurityService -> CloudServer | LightingService -> IoTDevice | ClimateControlService -> CloudServer | EntertainmentService -> CloudServer}
# (CloudServer pid=60507) 17:18:31 | INFO | ClimateControlService - Service ClimateControlService, 0 -  Unicasts in: 0.08475899696350098, expected = 0.07378732659819606
# (CloudServer pid=60507) 17:18:31 | INFO | SecurityService - Service SecurityService, 0 -  Unicasts in: 0.08748626708984375, expected = 0.07378463047707134
# (IoTDevice pid=60508) 17:18:31 | INFO | LightingService - Service LightingService, 0 -  Unicasts in: 0.0608828067779541, expected = 0.05089914468181257
# (IoTDevice pid=60508) 17:18:31 | INFO | LightingService - Service LightingService, 0 - Broadcasts in: 0.05602407455444336, expected = 0.05089914468181257
# (CloudServer pid=60507) 17:18:31 | INFO | ClimateControlService - Service ClimateControlService, 0 - Broadcasts in: 0.07785511016845703, expected = 0.07378732659819606
# (CloudServer pid=60507) 17:18:31 | INFO | SecurityService - Service SecurityService, 0 - Broadcasts in: 0.07708406448364258, expected = 0.07378463047707134
# (EdgeSensor pid=60510) 17:18:31 | INFO | Gateway - Service Gateway, 0 -  Unicasts in: 0.23218584060668945, expected = 0.21346053400190365
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | Simulation - Event Tick-11 fired.
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | Simulation - Event Enact-11 fired.
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 2.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 0.0, 'availability': 0.8, 'processing_time': 1.0, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:31 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 6, 'storage': 105, 'gpu': 2, 'availability': 0.9424287152135363, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | Simulation - Event Tick-12 fired.
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | Simulation - Event Enact-12 fired.
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 6.0, 'storage': 7.0, 'gpu': 0.0, 'availability': 0.8, 'processing_time': 1.0, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 5, 'storage': 98, 'gpu': 2, 'availability': 0.937740932720986, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 5.0, 'ram': 7.0, 'storage': 18.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.5, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 46, 'storage': 144, 'gpu': 8, 'availability': 0.9713318517779133, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | Simulation - Event Tick-13 fired.
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | Simulation - Event Enact-13 fired.
# (EdgeGateway pid=60506) 17:18:32 | INFO | LightingService - Service LightingService, 1 -  Unicasts in: 0.0021059513092041016, expected = 0
# (EdgeGateway pid=60506) 17:18:32 | INFO | LightingService - Service LightingService, 1 - Broadcasts in: 0.0027129650115966797, expected = 0
# (EdgeGateway pid=60506) 17:18:32 | INFO | SecurityService - Service SecurityService, 1 -  Unicasts in: 0.05974984169006348, expected = 0.05065778410429112
# (EdgeGateway pid=60506) 17:18:32 | INFO | Gateway - Service Gateway, 0 -  Unicasts in: 0.06043291091918945, expected = 0.050656004612166405
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:32 | INFO | SecurityService - Service SecurityService, 1 - Broadcasts in: 0.05540871620178223, expected = 0.05065778410429112
# (EdgeGateway pid=60506) 17:18:32 | INFO | Gateway - Service Gateway, 0 - Broadcasts in: 0.05472898483276367, expected = 0.050656004612166405
# (CloudStorage pid=60509) 17:18:32 | INFO | EntertainmentService - Service EntertainmentService, 1 -  Unicasts in: 0.06067299842834473, expected = 0.05265906461987539
# (CloudStorage pid=60509) 17:18:32 | INFO | ClimateControlService - Service ClimateControlService, 1 -  Unicasts in: 0.06133413314819336, expected = 0.05265928828509907
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | Simulation - Event Tick-14 fired.
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | Simulation - Event Enact-14 fired.
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:32 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:32 | INFO | EntertainmentService - Service EntertainmentService, 1 - Broadcasts in: 0.057914018630981445, expected = 0.05265906461987539
# (CloudStorage pid=60509) 17:18:32 | INFO | ClimateControlService - Service ClimateControlService, 1 - Broadcasts in: 0.05793571472167969, expected = 0.05265928828509907
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Tick-15 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Enact-15 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Tick-16 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Enact-16 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:33 | INFO | LightingService - Service LightingService, 2 -  Unicasts in: 0.0014178752899169922, expected = 0
# (EdgeGateway pid=60506) 17:18:33 | INFO | LightingService - Service LightingService, 2 - Broadcasts in: 0.0015442371368408203, expected = 0
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Tick-17 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Enact-17 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:33 | INFO | SecurityService - Service SecurityService, 2 -  Unicasts in: 0.05934286117553711, expected = 0.05065738591424587
# (EdgeGateway pid=60506) 17:18:33 | INFO | Gateway - Service Gateway, 1 -  Unicasts in: 0.06156182289123535, expected = 0.05065563055485117
# (EdgeGateway pid=60506) 17:18:33 | INFO | SecurityService - Service SecurityService, 2 - Broadcasts in: 0.05462312698364258, expected = 0.05065738591424587
# (EdgeGateway pid=60506) 17:18:33 | INFO | Gateway - Service Gateway, 1 - Broadcasts in: 0.054662227630615234, expected = 0.05065563055485117
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Tick-18 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | Simulation - Event Enact-18 fired.
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:33 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:33 | INFO | EntertainmentService - Service EntertainmentService, 2 -  Unicasts in: 0.05628228187561035, expected = 0.050657872824369315
# (CloudStorage pid=60509) 17:18:33 | INFO | ClimateControlService - Service ClimateControlService, 2 -  Unicasts in: 0.056513071060180664, expected = 0.050658087790355716
# (CloudStorage pid=60509) 17:18:33 | INFO | EntertainmentService - Service EntertainmentService, 2 - Broadcasts in: 0.0561370849609375, expected = 0.050657872824369315
# (CloudStorage pid=60509) 17:18:33 | INFO | ClimateControlService - Service ClimateControlService, 2 - Broadcasts in: 0.05597734451293945, expected = 0.050658087790355716
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Tick-19 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Enact-19 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Tick-20 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Enact-20 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:34 | INFO | LightingService - Service LightingService, 3 -  Unicasts in: 0.002010822296142578, expected = 0
# (EdgeGateway pid=60506) 17:18:34 | INFO | LightingService - Service LightingService, 3 - Broadcasts in: 0.0019268989562988281, expected = 0
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Tick-21 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Enact-21 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:34 | INFO | SecurityService - Service SecurityService, 3 -  Unicasts in: 0.05926966667175293, expected = 0.04965835445702238
# (EdgeGateway pid=60506) 17:18:34 | INFO | Gateway - Service Gateway, 2 -  Unicasts in: 0.06044292449951172, expected = 0.04965654039806547
# (EdgeGateway pid=60506) 17:18:34 | INFO | SecurityService - Service SecurityService, 3 - Broadcasts in: 0.05509614944458008, expected = 0.04965835445702238
# (EdgeGateway pid=60506) 17:18:34 | INFO | Gateway - Service Gateway, 2 - Broadcasts in: 0.05451178550720215, expected = 0.04965654039806547
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Tick-22 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | Simulation - Event Enact-22 fired.
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:34 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:34 | INFO | EntertainmentService - Service EntertainmentService, 3 -  Unicasts in: 0.058673858642578125, expected = 0.0526586105544087
# (CloudStorage pid=60509) 17:18:34 | INFO | ClimateControlService - Service ClimateControlService, 3 -  Unicasts in: 0.05929708480834961, expected = 0.05265883090528589
# (CloudStorage pid=60509) 17:18:35 | INFO | EntertainmentService - Service EntertainmentService, 3 - Broadcasts in: 0.06444287300109863, expected = 0.05365894952348087
# (CloudStorage pid=60509) 17:18:35 | INFO | ClimateControlService - Service ClimateControlService, 3 - Broadcasts in: 0.06360411643981934, expected = 0.05365917234858486
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Tick-23 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Enact-23 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Tick-24 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Enact-24 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:35 | INFO | LightingService - Service LightingService, 4 -  Unicasts in: 0.0029430389404296875, expected = 0
# (EdgeGateway pid=60506) 17:18:35 | INFO | LightingService - Service LightingService, 4 - Broadcasts in: 0.002579927444458008, expected = 0
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Tick-25 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Enact-25 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:36 | INFO | SecurityService - Service SecurityService, 4 -  Unicasts in: 0.05604219436645508, expected = 0.04766170789649542
# (EdgeGateway pid=60506) 17:18:36 | INFO | Gateway - Service Gateway, 3 -  Unicasts in: 0.05777692794799805, expected = 0.047659690598782556
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Tick-26 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | Simulation - Event Enact-26 fired.
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:35 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:36 | INFO | SecurityService - Service SecurityService, 4 - Broadcasts in: 0.05449175834655762, expected = 0.04866093861326552
# (EdgeGateway pid=60506) 17:18:36 | INFO | Gateway - Service Gateway, 3 - Broadcasts in: 0.05252885818481445, expected = 0.04865896793877872
# (CloudStorage pid=60509) 17:18:36 | INFO | ClimateControlService - Service ClimateControlService, 4 -  Unicasts in: 0.05643105506896973, expected = 0.05165850935188783
# (CloudStorage pid=60509) 17:18:36 | INFO | EntertainmentService - Service EntertainmentService, 4 -  Unicasts in: 0.05648469924926758, expected = 0.051658291331107734
# (CloudStorage pid=60509) 17:18:36 | INFO | ClimateControlService - Service ClimateControlService, 4 - Broadcasts in: 0.056902170181274414, expected = 0.05165850935188783
# (CloudStorage pid=60509) 17:18:36 | INFO | EntertainmentService - Service EntertainmentService, 4 - Broadcasts in: 0.05688333511352539, expected = 0.051658291331107734
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | Simulation - Event Tick-27 fired.
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | Simulation - Event Enact-27 fired.
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | Simulation - Event Tick-28 fired.
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | Simulation - Event Enact-28 fired.
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:36 | INFO | LightingService - Service LightingService, 5 -  Unicasts in: 0.00189208984375, expected = 0
# (EdgeGateway pid=60506) 17:18:36 | INFO | LightingService - Service LightingService, 5 - Broadcasts in: 0.0016200542449951172, expected = 0
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | Simulation - Event Tick-29 fired.
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | Simulation - Event Enact-29 fired.
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:36 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Tick-30 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Enact-30 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:37 | INFO | SecurityService - Service SecurityService, 5 -  Unicasts in: 0.058164119720458984, expected = 0.04966104169247044
# (EdgeGateway pid=60506) 17:18:37 | INFO | Gateway - Service Gateway, 4 -  Unicasts in: 0.05908703804016113, expected = 0.0496590647707591
# (EdgeGateway pid=60506) 17:18:37 | INFO | SecurityService - Service SecurityService, 5 - Broadcasts in: 0.054763078689575195, expected = 0.04966104169247044
# (EdgeGateway pid=60506) 17:18:37 | INFO | Gateway - Service Gateway, 4 - Broadcasts in: 0.05338883399963379, expected = 0.0496590647707591
# (CloudStorage pid=60509) 17:18:37 | INFO | ClimateControlService - Service ClimateControlService, 5 -  Unicasts in: 0.05965733528137207, expected = 0.053658717433728215
# (CloudStorage pid=60509) 17:18:37 | INFO | EntertainmentService - Service EntertainmentService, 5 -  Unicasts in: 0.059645891189575195, expected = 0.05365849790510868
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Tick-31 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Enact-31 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:37 | INFO | ClimateControlService - Service ClimateControlService, 5 - Broadcasts in: 0.058013916015625, expected = 0.053658717433728215
# (CloudStorage pid=60509) 17:18:37 | INFO | EntertainmentService - Service EntertainmentService, 5 - Broadcasts in: 0.05790305137634277, expected = 0.05365849790510868
# (EdgeGateway pid=60506) 17:18:37 | INFO | LightingService - Service LightingService, 6 -  Unicasts in: 0.0014128684997558594, expected = 0
# (EdgeGateway pid=60506) 17:18:37 | INFO | LightingService - Service LightingService, 6 - Broadcasts in: 0.0014867782592773438, expected = 0
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Tick-32 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Enact-32 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Tick-33 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | Simulation - Event Enact-33 fired.
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:37 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Tick-34 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Enact-34 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:38 | INFO | SecurityService - Service SecurityService, 6 -  Unicasts in: 0.06216001510620117, expected = 0.05366230165871731
# (EdgeGateway pid=60506) 17:18:38 | INFO | Gateway - Service Gateway, 5 -  Unicasts in: 0.06438183784484863, expected = 0.05366024837541525
# (EdgeGateway pid=60506) 17:18:38 | INFO | SecurityService - Service SecurityService, 6 - Broadcasts in: 0.059108734130859375, expected = 0.05366230165871731
# (EdgeGateway pid=60506) 17:18:38 | INFO | Gateway - Service Gateway, 5 - Broadcasts in: 0.057328224182128906, expected = 0.05366024837541525
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Tick-35 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Enact-35 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:38 | INFO | ClimateControlService - Service ClimateControlService, 6 -  Unicasts in: 0.05788612365722656, expected = 0.05366110954305679
# (CloudStorage pid=60509) 17:18:38 | INFO | EntertainmentService - Service EntertainmentService, 6 -  Unicasts in: 0.057940006256103516, expected = 0.053660872680311694
# (CloudStorage pid=60509) 17:18:38 | INFO | ClimateControlService - Service ClimateControlService, 6 - Broadcasts in: 0.059082984924316406, expected = 0.05366110954305679
# (CloudStorage pid=60509) 17:18:38 | INFO | EntertainmentService - Service EntertainmentService, 6 - Broadcasts in: 0.05899405479431152, expected = 0.053660872680311694
# (EdgeGateway pid=60506) 17:18:38 | INFO | LightingService - Service LightingService, 7 -  Unicasts in: 0.0014960765838623047, expected = 0
# (EdgeGateway pid=60506) 17:18:38 | INFO | LightingService - Service LightingService, 7 - Broadcasts in: 0.0012347698211669922, expected = 0
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Tick-36 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Enact-36 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Tick-37 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | Simulation - Event Enact-37 fired.
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:38 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Tick-38 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Enact-38 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:39 | INFO | SecurityService - Service SecurityService, 7 -  Unicasts in: 0.06451106071472168, expected = 0.054660632797681186
# (EdgeGateway pid=60506) 17:18:39 | INFO | Gateway - Service Gateway, 6 -  Unicasts in: 0.06600499153137207, expected = 0.054658680657472224
# (EdgeGateway pid=60506) 17:18:39 | INFO | SecurityService - Service SecurityService, 7 - Broadcasts in: 0.05896401405334473, expected = 0.054660632797681186
# (EdgeGateway pid=60506) 17:18:39 | INFO | Gateway - Service Gateway, 6 - Broadcasts in: 0.0582118034362793, expected = 0.054658680657472224
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Tick-39 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Enact-39 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:39 | INFO | ClimateControlService - Service ClimateControlService, 7 -  Unicasts in: 0.05786490440368652, expected = 0.05266044843017921
# (CloudStorage pid=60509) 17:18:39 | INFO | EntertainmentService - Service EntertainmentService, 7 -  Unicasts in: 0.0579681396484375, expected = 0.05266021635810714
# (CloudStorage pid=60509) 17:18:39 | INFO | ClimateControlService - Service ClimateControlService, 7 - Broadcasts in: 0.05759692192077637, expected = 0.0526608990424241
# (CloudStorage pid=60509) 17:18:39 | INFO | EntertainmentService - Service EntertainmentService, 7 - Broadcasts in: 0.057505130767822266, expected = 0.05266066370504591
# (EdgeGateway pid=60506) 17:18:39 | INFO | LightingService - Service LightingService, 8 -  Unicasts in: 0.002061128616333008, expected = 0
# (EdgeGateway pid=60506) 17:18:39 | INFO | LightingService - Service LightingService, 8 - Broadcasts in: 0.0015292167663574219, expected = 0
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Tick-40 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Enact-40 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Tick-41 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | Simulation - Event Enact-41 fired.
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:39 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Tick-42 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Enact-42 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:40 | INFO | SecurityService - Service SecurityService, 8 -  Unicasts in: 0.0649106502532959, expected = 0.05566126583011638
# (EdgeGateway pid=60506) 17:18:40 | INFO | Gateway - Service Gateway, 7 -  Unicasts in: 0.06729507446289062, expected = 0.055659275324305285
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Tick-43 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Enact-43 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (EdgeGateway pid=60506) 17:18:40 | INFO | SecurityService - Service SecurityService, 8 - Broadcasts in: 0.06033730506896973, expected = 0.05466117195927768
# (EdgeGateway pid=60506) 17:18:40 | INFO | Gateway - Service Gateway, 7 - Broadcasts in: 0.05847597122192383, expected = 0.054659187142608326
# (CloudStorage pid=60509) 17:18:40 | INFO | ClimateControlService - Service ClimateControlService, 8 -  Unicasts in: 0.056865692138671875, expected = 0.05066127085348751
# (CloudStorage pid=60509) 17:18:40 | INFO | EntertainmentService - Service EntertainmentService, 8 -  Unicasts in: 0.057057857513427734, expected = 0.05066103282182624
# (CloudStorage pid=60509) 17:18:40 | INFO | ClimateControlService - Service ClimateControlService, 8 - Broadcasts in: 0.056693077087402344, expected = 0.05066127085348751
# (CloudStorage pid=60509) 17:18:40 | INFO | EntertainmentService - Service EntertainmentService, 8 - Broadcasts in: 0.05667304992675781, expected = 0.05066103282182624
# (EdgeGateway pid=60506) 17:18:40 | INFO | LightingService - Service LightingService, 9 -  Unicasts in: 0.002063274383544922, expected = 0
# (EdgeGateway pid=60506) 17:18:40 | INFO | LightingService - Service LightingService, 9 - Broadcasts in: 0.0018739700317382812, expected = 0
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Tick-44 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Enact-44 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeGateway | SecurityService -> EdgeGateway | LightingService -> EdgeGateway | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Tick-45 fired.
# (RemoteSimulator pid=60511) 17:18:40 | 🌘 ECLYPSE | Simulation - Event Enact-45 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | Simulation - Event Tick-46 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | Simulation - Event Enact-46 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | Simulation - Event Tick-47 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | Simulation - Event Enact-47 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 6.0, 'ram': 8.5, 'storage': 12.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 26, 'ram': 46, 'storage': 2141, 'gpu': 17, 'availability': 0.9786497074746027, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 2.0, 'ram': 3.0, 'storage': 8.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.5, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 78, 'gpu': 2, 'availability': 1, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | Simulation - Event Tick-48 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | Simulation - Event Enact-48 fired.
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 7.0, 'storage': 10.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.5, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 71, 'gpu': 2, 'availability': 1, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 5.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:41 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 32, 'storage': 202, 'gpu': 8, 'availability': 0.9594891606906936, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | Simulation - Event Tick-49 fired.
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | Simulation - Event Enact-49 fired.
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 6.0, 'storage': 7.0, 'gpu': 0.0, 'availability': 0.8, 'processing_time': 1.0, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 64, 'gpu': 2, 'availability': 1, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | Simulation - Event Tick-50 fired.
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | Simulation - Event Enact-50 fired.
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 2.0, 'ram': 3.0, 'storage': 8.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.5, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 67, 'gpu': 2, 'availability': 0.9968103038144699, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Link EdgeGateway -> IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'latency': 1000000000.0, 'bandwidth': 40.0}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'latency': 15, 'bandwidth': 39}
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | Simulation - Event Tick-51 fired.
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | Simulation - Event Enact-51 fired.
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:42 | 🌘 ECLYPSE | PlacementManager - {Gateway -> IoTDevice | SecurityService -> CloudStorage | LightingService -> CloudServer | ClimateControlService -> CloudServer | EntertainmentService -> CloudServer}
# (CloudServer pid=60507) 17:18:42 | INFO | ClimateControlService - Service ClimateControlService, 9 -  Unicasts in: 0.06110787391662598, expected = 0.05033698981099252
# (CloudServer pid=60507) 17:18:42 | INFO | LightingService - Service LightingService, 10 -  Unicasts in: 0.0611572265625, expected = 0.050335313816127304
# (CloudServer pid=60507) 17:18:42 | INFO | EntertainmentService - Service EntertainmentService, 9 -  Unicasts in: 0.07210898399353027, expected = 0.06261818210104081
# (CloudStorage pid=60509) 17:18:42 | INFO | SecurityService - Service SecurityService, 9 -  Unicasts in: 0.103302001953125, expected = 0.08535010698426192
# (CloudServer pid=60507) 17:18:42 | INFO | ClimateControlService - Service ClimateControlService, 9 - Broadcasts in: 0.05574321746826172, expected = 0.05033698981099252
# ...
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 7, 'storage': 286, 'gpu': 5, 'availability': 0.9920102214764326, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | Simulation - Event Tick-82 fired.
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | Simulation - Event Enact-82 fired.
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 5.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 80, 'gpu': 2, 'availability': 0.9889010472430948, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | Simulation - Event Tick-83 fired.
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | Simulation - Event Enact-83 fired.
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 5.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:50 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 8, 'storage': 262, 'gpu': 5, 'availability': 0.9934349696642852, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Tick-84 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Enact-84 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 5.0, 'ram': 8.0, 'storage': 12.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 2.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 75, 'gpu': 2, 'availability': 0.9853471932002602, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Tick-85 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Enact-85 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 8.0, 'ram': 13.0, 'storage': 25.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 81, 'gpu': 2, 'availability': 0.9849070550405746, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Tick-86 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Enact-86 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 6.0, 'ram': 7.5, 'storage': 18.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 81, 'gpu': 2, 'availability': 0.9846497868223713, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Tick-87 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | Simulation - Event Enact-87 fired.
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 6.0, 'storage': 15.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:51 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 29, 'ram': 71, 'storage': 3219, 'gpu': 28, 'availability': 0.9762879381728464, 'processing_time': 7.906020085560016, 'group': FAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | Simulation - Event Tick-88 fired.
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | Simulation - Event Enact-88 fired.
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | PlacementManager - {Gateway -> CloudServer | SecurityService -> CloudStorage | LightingService -> EdgeSensor | ClimateControlService -> CloudStorage | EntertainmentService -> CloudStorage}
# (CloudStorage pid=60509) 17:18:52 | INFO | EntertainmentService - Service EntertainmentService, 12 -  Unicasts in: 0.005568027496337891, expected = 0
# (CloudStorage pid=60509) 17:18:52 | INFO | EntertainmentService - Service EntertainmentService, 12 - Broadcasts in: 0.002126932144165039, expected = 0
# (CloudStorage pid=60509) 17:18:52 | INFO | ClimateControlService - Service ClimateControlService, 12 -  Unicasts in: 0.06495118141174316, expected = 0.05462190485014591
# (CloudStorage pid=60509) 17:18:52 | INFO | SecurityService - Service SecurityService, 12 -  Unicasts in: 0.0636599063873291, expected = 0.05461974822363989
# (EdgeSensor pid=60510) 17:18:52 | INFO | LightingService - Service LightingService, 13 -  Unicasts in: 0.08039402961730957, expected = 0.07078722734888448
# (CloudStorage pid=60509) 17:18:52 | INFO | ClimateControlService - Service ClimateControlService, 12 - Broadcasts in: 0.060498952865600586, expected = 0.05462190485014591
# (CloudStorage pid=60509) 17:18:52 | INFO | SecurityService - Service SecurityService, 12 - Broadcasts in: 0.059069156646728516, expected = 0.05461974822363989
# (EdgeSensor pid=60510) 17:18:52 | INFO | LightingService - Service LightingService, 13 - Broadcasts in: 0.07620406150817871, expected = 0.07078722734888448
# (CloudServer pid=60507) 17:18:52 | INFO | Gateway - Service Gateway, 10 -  Unicasts in: 0.2182619571685791, expected = 0.20000626597088828
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | Simulation - Event Tick-89 fired.
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | Simulation - Event Enact-89 fired.
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Link EdgeGateway -> IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'latency': 1000000000.0, 'bandwidth': 70.0}
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'latency': 13, 'bandwidth': 44}
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Link IoTDevice -> EdgeGateway not respected
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'latency': 1000000000.0, 'bandwidth': 70.0}
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'latency': 11, 'bandwidth': 50}
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | Simulation - Event Tick-90 fired.
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | Simulation - Event Enact-90 fired.
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 4.5, 'storage': 10.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:52 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 84, 'gpu': 2, 'availability': 0.9813429767561723, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Tick-91 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Enact-91 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 6.0, 'storage': 7.0, 'gpu': 0.0, 'availability': 0.8, 'processing_time': 1.0, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 84, 'gpu': 2, 'availability': 0.9792310154007788, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Tick-92 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Enact-92 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 7.0, 'ram': 9.5, 'storage': 23.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 7, 'storage': 295, 'gpu': 5, 'availability': 0.9828840628492137, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Tick-93 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Enact-93 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 4.5, 'storage': 10.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 77, 'gpu': 2, 'availability': 0.9776026181870109, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Tick-94 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | Simulation - Event Enact-94 fired.
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 3.0, 'ram': 5.0, 'storage': 13.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.0, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:53 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 78, 'gpu': 2, 'availability': 0.9821213404401318, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Tick-95 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Enact-95 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 4.5, 'storage': 10.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 77, 'gpu': 2, 'availability': 0.9837228847455999, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Tick-96 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Enact-96 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 6.0, 'storage': 15.0, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 1.0, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 80, 'gpu': 2, 'availability': 0.9852164683479481, 'processing_time': 19.448541887258536, 'group': IOT}
# (CloudServer pid=60507) 17:18:54 | INFO | EntertainmentService - Service EntertainmentService, 13 -  Unicasts in: 0.0027840137481689453, expected = 0
# (CloudServer pid=60507) 17:18:54 | INFO | EntertainmentService - Service EntertainmentService, 13 - Broadcasts in: 0.001959085464477539, expected = 0
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Tick-97 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Enact-97 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | PlacementManager - Placement of EchoApp on EchoInfrastructure
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | PlacementManager - {Gateway -> EdgeSensor | SecurityService -> CloudServer | LightingService -> IoTDevice | ClimateControlService -> EdgeGateway | EntertainmentService -> CloudServer}
# (CloudServer pid=60507) 17:18:54 | INFO | SecurityService - Service SecurityService, 13 -  Unicasts in: 0.0980222225189209, expected = 0.0907841517640173
# (EdgeGateway pid=60506) 17:18:54 | INFO | ClimateControlService - Service ClimateControlService, 13 -  Unicasts in: 0.10172796249389648, expected = 0.08183233078456828
# (IoTDevice pid=60508) 17:18:54 | INFO | LightingService - Service LightingService, 14 -  Unicasts in: 0.06593990325927734, expected = 0.058898341778468366
# (IoTDevice pid=60508) 17:18:54 | INFO | LightingService - Service LightingService, 14 - Broadcasts in: 0.06326603889465332, expected = 0.058898341778468366
# (CloudServer pid=60507) 17:18:54 | INFO | SecurityService - Service SecurityService, 13 - Broadcasts in: 0.09452080726623535, expected = 0.0907841517640173
# (EdgeGateway pid=60506) 17:18:54 | INFO | ClimateControlService - Service ClimateControlService, 13 - Broadcasts in: 0.08596611022949219, expected = 0.08183233078456828
# (EdgeSensor pid=60510) 17:18:54 | INFO | Gateway - Service Gateway, 10 -  Unicasts in: 0.19203901290893555, expected = 0.17351462563085224
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Tick-98 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | Simulation - Event Enact-98 fired.
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 2.0, 'ram': 4.0, 'storage': 10.0, 'gpu': 0.0, 'availability': 0.8, 'processing_time': 1.0, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:54 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 78, 'gpu': 2, 'availability': 0.9919304071659828, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | Simulation - Event Tick-99 fired.
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | Simulation - Event Enact-99 fired.
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | EchoInfrastructure - Node IoTDevice not respected
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 4.0, 'ram': 4.5, 'storage': 10.5, 'gpu': 1.0, 'availability': 0.9, 'processing_time': 0.1, 'group': CLOUD}
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 1, 'ram': 2, 'storage': 82, 'gpu': 2, 'availability': 0.9873939909605893, 'processing_time': 19.448541887258536, 'group': IOT}
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | EchoInfrastructure - Node EdgeSensor not respected
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | EchoInfrastructure - Required: {'cpu': 5.0, 'ram': 9.0, 'storage': 15.0, 'gpu': 0.0, 'availability': 0.85, 'processing_time': 1.0, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | EchoInfrastructure - Available: {'cpu': 8, 'ram': 7, 'storage': 276, 'gpu': 5, 'availability': 0.9999648151651731, 'processing_time': 11.153013371819931, 'group': NEAR_EDGE}
# (RemoteSimulator pid=60511) 17:18:55 | 🌘 ECLYPSE | Simulation - Event Stop-0 fired.

# %% [markdown]
# Finally we can run the simulation by starting it with the `start` method, then waiting for it to finish with the `wait` method:

# %%
simulation.start()
simulation.wait()

# %% [markdown]
# Once the simulation is finished, you can access the results by calling the `report` property on the simulation object. This will return a `eclypse.report.Report` object, a friendly interface to select and filter the results of the simulation, that will retrieve pandas dataframes for further analysis.
#
# For instance if you want to get only the metrics related to the application, you can use the `application` method on the report object:

# %%
simulation.report.application()
# Out:
#                      timestamp event_id  n_event    callback_id  \
# 0   2024-11-25 17:18:28.801103    enact        1  response_time
# 1   2024-11-25 17:18:29.059067    enact        2  response_time
# 2   2024-11-25 17:18:29.315538    enact        3  response_time
# 3   2024-11-25 17:18:29.571987    enact        4  response_time
# 4   2024-11-25 17:18:29.862237    enact        5  response_time
# ..                         ...      ...      ...            ...
# 95  2024-11-25 17:18:54.113919    enact       96  response_time
# 96  2024-11-25 17:18:54.372192    enact       97  response_time
# 97  2024-11-25 17:18:54.646392    enact       98  response_time
# 98  2024-11-25 17:18:54.908498    enact       99  response_time
# 99  2024-11-25 17:18:55.169265    enact      100  response_time
#
#    application_id      value
# 0         EchoApp        inf
# 1         EchoApp        inf
# 2         EchoApp        inf
# 3         EchoApp        inf
# 4         EchoApp        inf
# ..            ...        ...
# 95        EchoApp        inf
# 96        EchoApp        inf
# 97        EchoApp  51.140773
# 98        EchoApp        inf
# 99        EchoApp        inf
#
# [100 rows x 6 columns]
